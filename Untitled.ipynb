# %%
from BeautifulSoup import BeautifulSoup
import json
from collections import defaultdict
import pymongo

# %%
with open('./learnCode/packages/npm-container/.npm/package/node_modules/wappalyzer/apps.json', 'rb') as json_doc:
    json_string = json.load(json_doc)
    
all_app_terms = set()

for app in json_string['apps'].keys():
    app_text = app.lower()
    app_text = app_text.split()
    for app_item in app_text:
        if 'js' in app_item:
            app_items = app_item.split('js')
            for app_i in app_items:
                if len(app_i) > 1:
                    all_app_terms.add(app_i)
        all_app_terms.add(app_item)

# %%
with open('ps-htmlstring.html', 'rb') as html_string:
    soup = BeautifulSoup(html_string)

# %%
relevant_courses = defaultdict(list)

for course_result in soup.findAll('div', {'class': 'search-result columns'}):
    course_title = course_result.find('a').text
    course_level = course_result.find('div', {'class': 'search-result__level'}).text
    course_date = course_result.find('div', {'class': 'search-result__date'}).text
    course_length = course_result.find('div', {'class': 'search-result__length show-for-large-up'}).text
    course_link = course_result.find('a').attrs[0][1]
    
    ratings = course_result.find('div', {'class':"search-result__rating show-for-xlarge-up"}).text
    ratings = ratings.replace("(", "")
    ratings = ratings.replace(")", "")
    
    course_rating_out_of_5 = 5 - len(course_result.findAll('i', {'class': 'fa fa-star gray'}))
    
#     if '2015' in course_date or '2016' in course_date:
    if course_level in {'Beginner', 'Intermediate'}:
        if course_rating_out_of_5 >= 4:
            course_name = set(course_title.lower().split(" "))

            categories = set()
            for app_term in all_app_terms:
                if len(app_term) > 1:
                    if app_term in course_name:
                        categories.add(app_term)

            if len(categories) > 0:

                course_info = {
                    'course_title': course_title,
                    'course_level': course_level,
                    'course_length': course_length,
                    'course_date': course_date,
                    'categories': list(categories),
                    'course_rating': course_rating_out_of_5,
                    'course_link': course_link,
                    'num_ratings': ratings
                }

                for category in categories:
                    relevant_courses[category].append(course_info)

# %%
client = pymongo.MongoClient(host="127.0.0.1", port=3001)
meteordb = client['meteor']
lessons_coll = meteordb['lessons']

for course_cat, relevant_cs in relevant_courses.iteritems():
    lessons_coll.insert({'courseCategory': course_cat, 'courseInfo': relevant_cs})

# %%
lessons_coll.find_one({"courseCategory":'jquery'})
# Out:
# {u'_id': ObjectId('56c8e93f7653534c517ea613'),
#  u'courseCategory': u'jquery',
#  u'courseInfo': [{u'categories': [u'jquery', u'advanced', u'pure'],
#    u'course_date': u'Jan 4 2016',
#    u'course_length': u'8h 59m',
#    u'course_level': u'Beginner',
#    u'course_link': u'/courses/advanced-js-jquery-pure-dom-scripting-fundamentals',
#    u'course_rating': 4,
#    u'course_title': u'JavaScript: Advanced Fundamentals to jQuery &amp; Pure DOM Scripting',
#    u'num_ratings': u'61'},
#   {u'categories': [u'jquery', u'bootstrap'],
#    u'course_date': u'Jun 11 2015',
#    u'course_length': u'3h 19m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/extending-bootstrap-css-javascript-jquery',
#    u'course_rating': 5,
#    u'course_title': u'Extending Bootstrap with CSS, JavaScript, and jQuery',
#    u'num_ratings': u'163'},
#   {u'categories': [u'jquery', u'asp.net', u'javascript'],
#    u'course_date': u'Jan 20 2009',
#    u'course_length': u'2h 22m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/aspdotnet-ajax-jscript',
#    u'course_rating': 5,
#    u'course_title': u'ASP.NET Ajax JavaScript and jQuery',
#    u'num_ratings': u'407'},
#   {u'categories': [u'jquery', u'javascript'],
#    u'course_date': u'Feb 18 2013',
#    u'course_length': u'3h 34m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/introduction-javascript-jquery',
#    u'course_rating': 4,
#    u'course_title': u'Introduction to JavaScript &amp; jQuery',
#    u'num_ratings': u'472'},
#   {u'categories': [u'jquery', u'bootstrap'],
#    u'course_date': u'Jan 8 2014',
#    u'course_length': u'3h 34m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/jquery-forms-bootstrap3',
#    u'course_rating': 5,
#    u'course_title': u'jQuery Forms and Bootstrap 3',
#    u'num_ratings': u'474'},
#   {u'categories': [u'jquery'],
#    u'course_date': u'Feb 20 2011',
#    u'course_length': u'5h 18m',
#    u'course_level': u'Beginner',
#    u'course_link': u'/courses/jquery-fundamentals',
#    u'course_rating': 5,
#    u'course_title': u'jQuery Fundamentals',
#    u'num_ratings': u'3842'},
#   {u'categories': [u'jquery'],
#    u'course_date': u'Feb 18 2013',
#    u'course_length': u'3h 35m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/jquery-in-depth',
#    u'course_rating': 4,
#    u'course_title': u'jQuery In-Depth',
#    u'num_ratings': u'142'},
#   {u'categories': [u'jquery', u'asp.net', u'mobile'],
#    u'course_date': u'Apr 26 2012',
#    u'course_length': u'1h 47m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/jquery-mobile',
#    u'course_rating': 5,
#    u'course_title': u'jQuery Mobile and ASP.NET MVC 4',
#    u'num_ratings': u'527'},
#   {u'categories': [u'jquery'],
#    u'course_date': u'Jul 18 2013',
#    u'course_length': u'4h 23m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/jquery-tips-and-tricks',
#    u'course_rating': 5,
#    u'course_title': u'jQuery Tips and Tricks',
#    u'num_ratings': u'380'},
#   {u'categories': [u'jquery', u'web'],
#    u'course_date': u'Aug 28 2012',
#    u'course_length': u'6h 25m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/spa',
#    u'course_rating': 5,
#    u'course_title': u'Single Page Apps with HTML5, Web API, Knockout and jQuery',
#    u'num_ratings': u'1204'},
#   {u'categories': [u'jquery', u'asp.net', u'code'],
#    u'course_date': u'Mar 2 2012',
#    u'course_length': u'5h 4m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/web-development',
#    u'course_rating': 5,
#    u'course_title': u'Building ASP.NET MVC Apps with EF Code First, HTML5, and jQuery',
#    u'num_ratings': u'725'},
#   {u'categories': [u'jquery'],
#    u'course_date': u'Jun 28 2013',
#    u'course_length': u'2h 7m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/fixing-common-jquery-bugs',
#    u'course_rating': 5,
#    u'course_title': u'Fixing Common jQuery Bugs',
#    u'num_ratings': u'136'},
#   {u'categories': [u'jquery', u'javascript', u'advanced'],
#    u'course_date': u'Nov 13 2013',
#    u'course_length': u'3h 16m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/javascript-jquery-advanced-techniques',
#    u'course_rating': 5,
#    u'course_title': u'Advanced Techniques in JavaScript and jQuery',
#    u'num_ratings': u'448'},
#   {u'categories': [u'jquery'],
#    u'course_date': u'Oct 8 2013',
#    u'course_length': u'3h 41m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/jquery-animation',
#    u'course_rating': 5,
#    u'course_title': u'jQuery Animation',
#    u'num_ratings': u'135'},
#   {u'categories': [u'jquery', u'ui'],
#    u'course_date': u'Feb 18 2013',
#    u'course_length': u'3h 26m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/jquery-plugins-jquery-ui',
#    u'course_rating': 4,
#    u'course_title': u'jQuery Plugins &amp; jQuery UI',
#    u'num_ratings': u'68'},
#   {u'categories': [u'jquery'],
#    u'course_date': u'Feb 27 2012',
#    u'course_length': u'1h 1m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/jquery-templates',
#    u'course_rating': 5,
#    u'course_title': u'jQuery Template Fundamentals',
#    u'num_ratings': u'151'},
#   {u'categories': [u'jquery', u'ui'],
#    u'course_date': u'Nov 27 2011',
#    u'course_length': u'1h 54m',
#    u'course_level': u'Beginner',
#    u'course_link': u'/courses/jqueryui',
#    u'course_rating': 5,
#    u'course_title': u'jQuery UI',
#    u'num_ratings': u'765'},
#   {u'categories': [u'jquery'],
#    u'course_date': u'Jan 16 2014',
#    u'course_length': u'3h 6m',
#    u'course_level': u'Intermediate',
#    u'course_link': u'/courses/useful-jquery-plugins',
#    u'course_rating': 5,
#    u'course_title': u'Useful jQuery Plugins',
#    u'num_ratings': u'86'}]}

# %%
relevant_courses['angular']
# Out:
# [{'categories': [u'react', u'angular', u'for'],
#   'course_date': u'Feb 10 2016',
#   'course_length': u'2h 52m',
#   'course_level': u'Intermediate',
#   'course_link': u'/courses/react-flux-angular',
#   'course_rating': 5,
#   'course_title': u'React and Flux for Angular Developers',
#   'num_ratings': u'30'},
#  {'categories': [u'angular'],
#   'course_date': u'Feb 16 2016',
#   'course_length': u'2h 45m',
#   'course_level': u'Beginner',
#   'course_link': u'/courses/angular-material-fundamentals',
#   'course_rating': 4,
#   'course_title': u'Angular Material Fundamentals',
#   'num_ratings': u'13'},
#  {'categories': [u'asp.net', u'connect', u'for', u'angular'],
#   'course_date': u'Dec 20 2015',
#   'course_length': u'4h 9m',
#   'course_level': u'Intermediate',
#   'course_link': u'/courses/oauth2-openid-connect-angular-aspdotnet',
#   'course_rating': 5,
#   'course_title': u'OAuth2 and OpenID Connect Strategies for Angular and ASP.NET',
#   'num_ratings': u'131'},
#  {'categories': [u'asp.net', u'web', u'api', u'angular'],
#   'course_date': u'Oct 26 2015',
#   'course_length': u'1h 2m',
#   'course_level': u'Beginner',
#   'course_link': u'/courses/authenticating-angular-spa-aspnet-webapi-auth0',
#   'course_rating': 5,
#   'course_title': u'Authenticating Your Angular SPA with ASP.NET Web API and Auth0',
#   'num_ratings': u'180'},
#  {'categories': [u'angular'],
#   'course_date': u'Sep 4 2015',
#   'course_length': u'2h 14m',
#   'course_level': u'Intermediate',
#   'course_link': u'/courses/angular-routing-in-depth',
#   'course_rating': 5,
#   'course_title': u'Angular Routing In-depth',
#   'num_ratings': u'297'},
#  {'categories': [u'angular', u'realtime'],
#   'course_date': u'Sep 2 2015',
#   'course_length': u'3h 26m',
#   'course_level': u'Intermediate',
#   'course_link': u'/courses/building-realtime-angular-controls',
#   'course_rating': 5,
#   'course_title': u'Building Realtime Angular Controls',
#   'num_ratings': u'65'},
#  {'categories': [u'angular'],
#   'course_date': u'May 16 2013',
#   'course_length': u'6h 49m',
#   'course_level': u'Intermediate',
#   'course_link': u'/courses/angularjs-fundamentals',
#   'course_rating': 5,
#   'course_title': u'Angular Fundamentals',
#   'num_ratings': u'3839'},
#  {'categories': [u'angular'],
#   'course_date': u'Aug 10 2015',
#   'course_length': u'3h 33m',
#   'course_level': u'Intermediate',
#   'course_link': u'/courses/angular-typescript',
#   'course_rating': 5,
#   'course_title': u'Angular with TypeScript',
#   'num_ratings': u'632'},
#  {'categories': [u'web', u'api', u'angular'],
#   'course_date': u'Apr 15 2015',
#   'course_length': u'5h 15m',
#   'course_level': u'Intermediate',
#   'course_link': u'/courses/angular-web-api-front-back',
#   'course_rating': 5,
#   'course_title': u'Angular Front to Back with Web API',
#   'num_ratings': u'984'},
#  {'categories': [u'angular'],
#   'course_date': u'Apr 24 2015',
#   'course_length': u'1h 54m',
#   'course_level': u'Beginner',
#   'course_link': u'/courses/play-by-play-angular-testing-papa-bell',
#   'course_rating': 5,
#   'course_title': u'Play by Play: Angular Testing with John Papa and Ward Bell',
#   'num_ratings': u'210'},
#  {'categories': [u'angular'],
#   'course_date': u'Oct 24 2013',
#   'course_length': u'5h 3m',
#   'course_level': u'Intermediate',
#   'course_link': u'/courses/angular-best-practices',
#   'course_rating': 5,
#   'course_title': u'Angular Best Practices',
#   'num_ratings': u'1090'},
#  {'categories': [u'node.js', u'angular'],
#   'course_date': u'Jan 30 2014',
#   'course_length': u'4h 4m',
#   'course_level': u'Intermediate',
#   'course_link': u'/courses/building-angularjs-nodejs-apps-mean',
#   'course_rating': 5,
#   'course_title': u'Building Angular and Node.js Apps with the MEAN Stack',
#   'num_ratings': u'815'},
#  {'categories': [u'angular', u'service'],
#   'course_date': u'Sep 18 2014',
#   'course_length': u'12h 32m',
#   'course_level': u'Intermediate',
#   'course_link': u'/courses/building-multi-client-end-to-end-soa-angular',
#   'course_rating': 5,
#   'course_title': u'Building End-to-End Multi-Client Service Oriented Applications - Angular',
#   'num_ratings': u'622'},
#  {'categories': [u'app', u'api', u'angular'],
#   'course_date': u'Feb 10 2015',
#   'course_length': u'3h 23m',
#   'course_level': u'Intermediate',
#   'course_link': u'/courses/two-tier-enterprise-app-api-development-angular-sails',
#   'course_rating': 5,
#   'course_title': u'Two Tier Enterprise App and API Development with Angular &amp; Sails',
#   'num_ratings': u'133'},
#  {'categories': [u'new', u'angular'],
#   'course_date': u'Dec 14 2014',
#   'course_length': u'2h 39m',
#   'course_level': u'Intermediate',
#   'course_link': u'/courses/angular-1-3',
#   'course_rating': 5,
#   'course_title': u"What's New in Angular 1.3",
#   'num_ratings': u'248'}]

# %%
# terms = defaultdict(int)

# apps_to_keep = []

# for course_cat, course_list in relevant_courses.iteritems():
#     for course in course_list:
#         categories = course['categories']
#         for category in categories:
#             terms[category] += 1
            
# for app in json_string['apps'].keys():
#     app_text = app.lower()
#     app_text = app_text.split()
#     for app_item in app_text:
#         if 'js' in app_item:
#             app_items = app_item.split('js')
#             for app_i in app_items:
#                 if len(app_i) > 1:
#                     app_text.append(app_i)
                
#     for item in app_text:
#         if item in terms:
#             apps_to_keep.append(app)
#             break
            
# apps_to_delete = []

# for app in json_string['apps'].keys():
#     if app not in apps_to_keep:
#         apps_to_delete.append(app)
        
# for app in apps_to_delete:
#     print app
#     del json_string['apps'][app]

# %%
relevant_courses
# Out:
# defaultdict(list,
#             {u'active': [{'categories': [u'active', u'for'],
#                'course_date': u'May 29 2013',
#                'course_length': u'1h 40m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/active-directory-programming',
#                'course_rating': 4,
#                'course_title': u'Active Directory Programming for Developers',
#                'num_ratings': u'274'}],
#              u'ad': [{'categories': [u'ad', u'sql'],
#                'course_date': u'Dec 5 2013',
#                'course_length': u'7h 15m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/sqlserver-optimizing-adhoc-statement-performance',
#                'course_rating': 5,
#                'course_title': u'SQL Server: Optimizing Ad Hoc Statement Performance',
#                'num_ratings': u'330'}],
#              u'adobe': [{'categories': [u'adobe', u'muse'],
#                'course_date': u'Oct 3 2014',
#                'course_length': u'3h 32m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/adobe-muse-fundamentals',
#                'course_rating': 5,
#                'course_title': u'Adobe Muse Fundamentals',
#                'num_ratings': u'33'}],
#              u'advanced': [{'categories': [u'jquery', u'advanced', u'pure'],
#                'course_date': u'Jan 4 2016',
#                'course_length': u'8h 59m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/advanced-js-jquery-pure-dom-scripting-fundamentals',
#                'course_rating': 4,
#                'course_title': u'JavaScript: Advanced Fundamentals to jQuery &amp; Pure DOM Scripting',
#                'num_ratings': u'61'},
#               {'categories': [u'advanced'],
#                'course_date': u'Sep 28 2015',
#                'course_length': u'6h 54m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/wpf-mvvm-advanced-model-treatment',
#                'course_rating': 5,
#                'course_title': u'WPF and MVVM: Advanced Model Treatment',
#                'num_ratings': u'127'},
#               {'categories': [u'advanced'],
#                'course_date': u'Mar 17 2015',
#                'course_length': u'4h 44m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/ssis-advanced-part2',
#                'course_rating': 4,
#                'course_title': u'Advanced Integration Services - Part 2',
#                'num_ratings': u'76'},
#               {'categories': [u'advanced', u'server'],
#                'course_date': u'Apr 5 2010',
#                'course_length': u'12h 19m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/bts09-custom-ms',
#                'course_rating': 5,
#                'course_title': u'Advanced BizTalk Server 2009',
#                'num_ratings': u'15'},
#               {'categories': [u'web', u'sharepoint', u'for', u'advanced'],
#                'course_date': u'Sep 12 2012',
#                'course_length': u'5h 2m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/cpt-sp2010-web-designers-branding-adv',
#                'course_rating': 4,
#                'course_title': u'SharePoint 2010 for Web Designers - Part 5, Advanced Branding',
#                'num_ratings': u'71'},
#               {'categories': [u'jquery', u'javascript', u'advanced'],
#                'course_date': u'Nov 13 2013',
#                'course_length': u'3h 16m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/javascript-jquery-advanced-techniques',
#                'course_rating': 5,
#                'course_title': u'Advanced Techniques in JavaScript and jQuery',
#                'num_ratings': u'448'}],
#              u'advertising': [{'categories': [u'advertising'],
#                'course_date': u'Oct 15 2013',
#                'course_length': u'3h 24m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/understanding-profiting-online-advertising',
#                'course_rating': 5,
#                'course_title': u'Understanding and Profiting from On-line Advertising',
#                'num_ratings': u'77'}],
#              u'analytics': [{'categories': [u'analytics'],
#                'course_date': u'Jul 22 2013',
#                'course_length': u'3h 44m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/big-data-analytics-tableau',
#                'course_rating': 5,
#                'course_title': u'Big Data Analytics with Tableau',
#                'num_ratings': u'241'},
#               {'categories': [u'analytics', u'google'],
#                'course_date': u'Sep 17 2012',
#                'course_length': u'2h 15m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/google-analytics',
#                'course_rating': 4,
#                'course_title': u'Google Analytics Fundamentals',
#                'num_ratings': u'232'}],
#              u'angular': [{'categories': [u'react', u'angular', u'for'],
#                'course_date': u'Feb 10 2016',
#                'course_length': u'2h 52m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/react-flux-angular',
#                'course_rating': 5,
#                'course_title': u'React and Flux for Angular Developers',
#                'num_ratings': u'30'},
#               {'categories': [u'angular'],
#                'course_date': u'Feb 16 2016',
#                'course_length': u'2h 45m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/angular-material-fundamentals',
#                'course_rating': 4,
#                'course_title': u'Angular Material Fundamentals',
#                'num_ratings': u'13'},
#               {'categories': [u'asp.net', u'connect', u'for', u'angular'],
#                'course_date': u'Dec 20 2015',
#                'course_length': u'4h 9m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/oauth2-openid-connect-angular-aspdotnet',
#                'course_rating': 5,
#                'course_title': u'OAuth2 and OpenID Connect Strategies for Angular and ASP.NET',
#                'num_ratings': u'131'},
#               {'categories': [u'asp.net', u'web', u'api', u'angular'],
#                'course_date': u'Oct 26 2015',
#                'course_length': u'1h 2m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/authenticating-angular-spa-aspnet-webapi-auth0',
#                'course_rating': 5,
#                'course_title': u'Authenticating Your Angular SPA with ASP.NET Web API and Auth0',
#                'num_ratings': u'180'},
#               {'categories': [u'angular'],
#                'course_date': u'Sep 4 2015',
#                'course_length': u'2h 14m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angular-routing-in-depth',
#                'course_rating': 5,
#                'course_title': u'Angular Routing In-depth',
#                'num_ratings': u'297'},
#               {'categories': [u'angular', u'realtime'],
#                'course_date': u'Sep 2 2015',
#                'course_length': u'3h 26m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-realtime-angular-controls',
#                'course_rating': 5,
#                'course_title': u'Building Realtime Angular Controls',
#                'num_ratings': u'65'},
#               {'categories': [u'angular'],
#                'course_date': u'May 16 2013',
#                'course_length': u'6h 49m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angularjs-fundamentals',
#                'course_rating': 5,
#                'course_title': u'Angular Fundamentals',
#                'num_ratings': u'3839'},
#               {'categories': [u'angular'],
#                'course_date': u'Aug 10 2015',
#                'course_length': u'3h 33m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angular-typescript',
#                'course_rating': 5,
#                'course_title': u'Angular with TypeScript',
#                'num_ratings': u'632'},
#               {'categories': [u'web', u'api', u'angular'],
#                'course_date': u'Apr 15 2015',
#                'course_length': u'5h 15m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angular-web-api-front-back',
#                'course_rating': 5,
#                'course_title': u'Angular Front to Back with Web API',
#                'num_ratings': u'984'},
#               {'categories': [u'angular'],
#                'course_date': u'Apr 24 2015',
#                'course_length': u'1h 54m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/play-by-play-angular-testing-papa-bell',
#                'course_rating': 5,
#                'course_title': u'Play by Play: Angular Testing with John Papa and Ward Bell',
#                'num_ratings': u'210'},
#               {'categories': [u'angular'],
#                'course_date': u'Oct 24 2013',
#                'course_length': u'5h 3m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angular-best-practices',
#                'course_rating': 5,
#                'course_title': u'Angular Best Practices',
#                'num_ratings': u'1090'},
#               {'categories': [u'node.js', u'angular'],
#                'course_date': u'Jan 30 2014',
#                'course_length': u'4h 4m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-angularjs-nodejs-apps-mean',
#                'course_rating': 5,
#                'course_title': u'Building Angular and Node.js Apps with the MEAN Stack',
#                'num_ratings': u'815'},
#               {'categories': [u'angular', u'service'],
#                'course_date': u'Sep 18 2014',
#                'course_length': u'12h 32m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-multi-client-end-to-end-soa-angular',
#                'course_rating': 5,
#                'course_title': u'Building End-to-End Multi-Client Service Oriented Applications - Angular',
#                'num_ratings': u'622'},
#               {'categories': [u'app', u'api', u'angular'],
#                'course_date': u'Feb 10 2015',
#                'course_length': u'3h 23m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/two-tier-enterprise-app-api-development-angular-sails',
#                'course_rating': 5,
#                'course_title': u'Two Tier Enterprise App and API Development with Angular &amp; Sails',
#                'num_ratings': u'133'},
#               {'categories': [u'new', u'angular'],
#                'course_date': u'Dec 14 2014',
#                'course_length': u'2h 39m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angular-1-3',
#                'course_rating': 5,
#                'course_title': u"What's New in Angular 1.3",
#                'num_ratings': u'248'}],
#              u'angularjs': [{'categories': [u'asp.net', u'angularjs'],
#                'course_date': u'Dec 11 2015',
#                'course_length': u'2h 55m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/internationalization-angular-js-aspdotnet',
#                'course_rating': 4,
#                'course_title': u'Internationalization with AngularJS and ASP.NET',
#                'num_ratings': u'37'},
#               {'categories': [u'mobile', u'framework', u'angularjs'],
#                'course_date': u'Aug 25 2014',
#                'course_length': u'3h 12m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-mobile-apps-ionic-framework-angularjs',
#                'course_rating': 5,
#                'course_title': u'Building Mobile Apps With the Ionic Framework and AngularJS',
#                'num_ratings': u'936'},
#               {'categories': [u'angularjs'],
#                'course_date': u'Nov 17 2015',
#                'course_length': u'2h 23m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angularjs-ngmock-unit-testing',
#                'course_rating': 5,
#                'course_title': u'AngularJS Unit Testing in-depth, Using ngMock',
#                'num_ratings': u'144'},
#               {'categories': [u'asp.net', u'web', u'app', u'angularjs'],
#                'course_date': u'Oct 8 2015',
#                'course_length': u'9h 21m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/aspdotnet-5-ef7-bootstrap-angular-web-app',
#                'course_rating': 5,
#                'course_title': u'Building a Web App with ASP.NET 5, MVC 6, EF7 and AngularJS',
#                'num_ratings': u'1720'},
#               {'categories': [u'asp.net', u'angularjs'],
#                'course_date': u'Sep 8 2015',
#                'course_length': u'2h 59m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-strongly-typed-angularjs-apps-aspdotnet-mvc5',
#                'course_rating': 5,
#                'course_title': u'Building Strongly-typed AngularJS Apps with ASP.NET MVC 5',
#                'num_ratings': u'283'},
#               {'categories': [u'php', u'site', u'angularjs'],
#                'course_date': u'Jul 16 2015',
#                'course_length': u'2h 50m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angularjs-php-building-site',
#                'course_rating': 5,
#                'course_title': u'Building a Site with AngularJS and PHP',
#                'num_ratings': u'111'},
#               {'categories': [u'angularjs'],
#                'course_date': u'Apr 14 2015',
#                'course_length': u'1h 57m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angular-animating-apps',
#                'course_rating': 5,
#                'course_title': u'Animating AngularJS Applications',
#                'num_ratings': u'139'},
#               {'categories': [u'angularjs'],
#                'course_date': u'Nov 18 2013',
#                'course_length': u'4h 56m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angularjs-in-depth',
#                'course_rating': 4,
#                'course_title': u'AngularJS In-Depth',
#                'num_ratings': u'526'},
#               {'categories': [u'code', u'angularjs'],
#                'course_date': u'Oct 7 2014',
#                'course_length': u'3h 31m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/angularjs-patterns-clean-code',
#                'course_rating': 5,
#                'course_title': u'AngularJS Patterns: Clean Code',
#                'num_ratings': u'1206'},
#               {'categories': [u'node.js', u'for', u'angularjs'],
#                'course_date': u'Sep 18 2014',
#                'course_length': u'1h 53m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/continuous-integration-deployment-angularjs-nodejs',
#                'course_rating': 5,
#                'course_title': u'Continuous Integration and Deployment for AngularJS and Node.js',
#                'num_ratings': u'207'},
#               {'categories': [u'angularjs'],
#                'course_date': u'Oct 7 2014',
#                'course_length': u'1h 30m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/play-by-play-learning-angularjs-ken-cenerelli-john-papa',
#                'course_rating': 5,
#                'course_title': u'Play by Play: Learning AngularJS With Ken Cenerelli and John Papa',
#                'num_ratings': u'557'},
#               {'categories': [u'application', u'angularjs'],
#                'course_date': u'Dec 12 2013',
#                'course_length': u'2h 14m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/play-by-play-wahlin-allen',
#                'course_rating': 5,
#                'course_title': u'Play by Play: AngularJS Application Design with Scott Allen and Dan Wahlin',
#                'num_ratings': u'521'},
#               {'categories': [u'angularjs'],
#                'course_date': u'Feb 24 2015',
#                'course_length': u'3h 3m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angularjs-services-in-depth',
#                'course_rating': 5,
#                'course_title': u'AngularJS Services In-depth',
#                'num_ratings': u'465'},
#               {'categories': [u'angularjs'],
#                'course_date': u'Feb 4 2015',
#                'course_length': u'2h 27m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angularjs-security-fundamentals',
#                'course_rating': 4,
#                'course_title': u'AngularJS Security Fundamentals',
#                'num_ratings': u'432'},
#               {'categories': [u'sharepoint', u'angularjs'],
#                'course_date': u'Apr 24 2014',
#                'course_length': u'3h 36m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-sharepoint-apps-spa-angularjs',
#                'course_rating': 5,
#                'course_title': u'Building SharePoint Apps as Single Page Apps with AngularJS',
#                'num_ratings': u'253'},
#               {'categories': [u'ui', u'kendo', u'angularjs'],
#                'course_date': u'Oct 13 2014',
#                'course_length': u'1h 16m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/kendo-ui-angularjs-from-scratch',
#                'course_rating': 4,
#                'course_title': u'Kendo UI and AngularJS from Scratch',
#                'num_ratings': u'290'},
#               {'categories': [u'angularjs'],
#                'course_date': u'Jul 8 2014',
#                'course_length': u'1h 17m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/testing-angularjs-from-scratch',
#                'course_rating': 4,
#                'course_title': u'Testing AngularJS From Scratch',
#                'num_ratings': u'709'},
#               {'categories': [u'for', u'angularjs'],
#                'course_date': u'Dec 31 2014',
#                'course_length': u'3h 7m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/using-typescript-large-angularjs-apps',
#                'course_rating': 5,
#                'course_title': u'Using TypeScript for Large AngularJS Applications',
#                'num_ratings': u'340'}],
#              u'apache': [{'categories': [u'apache'],
#                'course_date': u'Oct 27 2015',
#                'course_length': u'4h 27m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/apache-spark-fundamentals',
#                'course_rating': 5,
#                'course_title': u'Apache Spark Fundamentals',
#                'num_ratings': u'117'},
#               {'categories': [u'apache'],
#                'course_date': u'Sep 10 2014',
#                'course_length': u'2h 21m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/apache-ant-fundamentals',
#                'course_rating': 5,
#                'course_title': u'Apache Ant Fundamentals',
#                'num_ratings': u'124'},
#               {'categories': [u'apache'],
#                'course_date': u'Feb 19 2015',
#                'course_length': u'4h 44m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/apache-camel-intro-integration',
#                'course_rating': 4,
#                'course_title': u'Introduction to Integration With Apache Camel',
#                'num_ratings': u'130'},
#               {'categories': [u'apache', u'search', u'solr'],
#                'course_date': u'Jun 22 2014',
#                'course_length': u'3h 32m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/enterprise-search-using-apache-solr',
#                'course_rating': 4,
#                'course_title': u'Getting Started with Enterprise Search Using Apache Solr',
#                'num_ratings': u'240'},
#               {'categories': [u'apache', u'web'],
#                'course_date': u'Apr 21 2014',
#                'course_length': u'3h 17m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-jax-ws-web-services-apache-cxf',
#                'course_rating': 5,
#                'course_title': u'Building JAX-WS Web Services with Apache CXF',
#                'num_ratings': u'164'}],
#              u'api': [{'categories': [u'web', u'api'],
#                'course_date': u'Jan 29 2016',
#                'course_length': u'2h 1m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/play-by-play-node-web-api-john-papa-sam-artioli',
#                'course_rating': 5,
#                'course_title': u'Play by Play: Building a Node Web API with Sam Artioli and John Papa',
#                'num_ratings': u'64'},
#               {'categories': [u'api'],
#                'course_date': u'Dec 14 2015',
#                'course_length': u'1h 52m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/scalable-aws-api-gateway',
#                'course_rating': 5,
#                'course_title': u'Building Scalable APIs with the AWS API Gateway',
#                'num_ratings': u'28'},
#               {'categories': [u'asp.net', u'web', u'api', u'angular'],
#                'course_date': u'Oct 26 2015',
#                'course_length': u'1h 2m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/authenticating-angular-spa-aspnet-webapi-auth0',
#                'course_rating': 5,
#                'course_title': u'Authenticating Your Angular SPA with ASP.NET Web API and Auth0',
#                'num_ratings': u'180'},
#               {'categories': [u'web', u'api', u'angular'],
#                'course_date': u'Apr 15 2015',
#                'course_length': u'5h 15m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/angular-web-api-front-back',
#                'course_rating': 5,
#                'course_title': u'Angular Front to Back with Web API',
#                'num_ratings': u'984'},
#               {'categories': [u'asp.net', u'api', u'for'],
#                'course_date': u'Mar 5 2015',
#                'course_length': u'5h 4m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-securing-restful-api-aspdotnet',
#                'course_rating': 5,
#                'course_title': u'Building and Securing a RESTful API for Multiple Clients in ASP.NET',
#                'num_ratings': u'796'},
#               {'categories': [u'asp.net', u'web', u'api'],
#                'course_date': u'Dec 11 2012',
#                'course_length': u'3h 15m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/aspnetwebapi',
#                'course_rating': 4,
#                'course_title': u'Introduction to the ASP.NET Web API',
#                'num_ratings': u'1391'},
#               {'categories': [u'asp.net', u'web', u'api'],
#                'course_date': u'Mar 4 2013',
#                'course_length': u'3h 51m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/aspnetwebapi-odata',
#                'course_rating': 5,
#                'course_title': u'Building ASP.NET Web API OData Services',
#                'num_ratings': u'434'},
#               {'categories': [u'api'],
#                'course_date': u'Jun 24 2013',
#                'course_length': u'2h 10m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/beginner-facebook-development',
#                'course_rating': 4,
#                'course_title': u'Introduction to the Facebook Graph API',
#                'num_ratings': u'58'},
#               {'categories': [u'framework', u'api', u'web'],
#                'course_date': u'May 1 2014',
#                'course_length': u'2h 35m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-web-apps-services-aspdotnet-ef-webapi',
#                'course_rating': 4,
#                'course_title': u'Building Web Apps &amp; Services with Entity Framework and Web API',
#                'num_ratings': u'684'},
#               {'categories': [u'api'],
#                'course_date': u'Sep 2 2014',
#                'course_length': u'4h 7m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/hack-your-api-first',
#                'course_rating': 5,
#                'course_title': u'Hack Your API First',
#                'num_ratings': u'341'},
#               {'categories': [u'web', u'api', u'business'],
#                'course_date': u'Jun 13 2013',
#                'course_length': u'4h 32m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/html5-line-of-business-applications',
#                'course_rating': 5,
#                'course_title': u'HTML5 Line of Business Apps with Bootstrap, MVC4 and Web API',
#                'num_ratings': u'713'},
#               {'categories': [u'asp.net', u'web', u'api'],
#                'course_date': u'Oct 1 2013',
#                'course_length': u'6h 14m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/implementing-restful-aspdotnet-web-api',
#                'course_rating': 5,
#                'course_title': u'Implementing an API in ASP.NET Web API',
#                'num_ratings': u'1336'},
#               {'categories': [u'asp.net', u'api'],
#                'course_date': u'Feb 19 2015',
#                'course_length': u'6h 19m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/integrating-aspdotnet-mvc-facebook-graphapi',
#                'course_rating': 5,
#                'course_title': u'Integrating ASP.NET MVC With the Facebook Graph API',
#                'num_ratings': u'61'},
#               {'categories': [u'api', u'sharepoint'],
#                'course_date': u'Sep 23 2010',
#                'course_length': u'3h 28m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/sp2010-client-object-model',
#                'course_rating': 5,
#                'course_title': u'SharePoint Development with the CSOM and REST API',
#                'num_ratings': u'71'},
#               {'categories': [u'app', u'api', u'angular'],
#                'course_date': u'Feb 10 2015',
#                'course_length': u'3h 23m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/two-tier-enterprise-app-api-development-angular-sails',
#                'course_rating': 5,
#                'course_title': u'Two Tier Enterprise App and API Development with Angular &amp; Sails',
#                'num_ratings': u'133'},
#               {'categories': [u'web', u'api'],
#                'course_date': u'Apr 11 2014',
#                'course_length': u'6h 12m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/webapi-v2-security',
#                'course_rating': 5,
#                'course_title': u'Web API v2 Security',
#                'num_ratings': u'850'},
#               {'categories': [u'api', u'javascript'],
#                'course_date': u'Oct 14 2014',
#                'course_length': u'2h 7m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/getting-started-mapbox-javascript',
#                'course_rating': 5,
#                'course_title': u'Getting Started With the Mapbox JavaScript API',
#                'num_ratings': u'23'},
#               {'categories': [u'api', u'java', u'for'],
#                'course_date': u'Jan 8 2015',
#                'course_length': u'2h 2m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/java-api-websockets-introduction',
#                'course_rating': 5,
#                'course_title': u'Introduction to the Java API for WebSockets',
#                'num_ratings': u'50'},
#               {'categories': [u'api', u'java'],
#                'course_date': u'May 18 2014',
#                'course_length': u'3h 41m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/java-persistence-api-21',
#                'course_rating': 5,
#                'course_title': u'Java Persistence API (JPA) 2.1',
#                'num_ratings': u'289'},
#               {'categories': [u'api', u'ruby'],
#                'course_date': u'Mar 15 2012',
#                'course_length': u'1h 30m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/play-by-play-jim-weirich',
#                'course_rating': 4,
#                'course_title': u'Play by Play: Ruby API Design with Jim Weirich',
#                'num_ratings': u'20'},
#               {'categories': [u'api', u'sharepoint'],
#                'course_date': u'May 28 2013',
#                'course_length': u'6h 41m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/sharepoint-2013-client-object-model-rest',
#                'course_rating': 5,
#                'course_title': u'SharePoint 2013 Development: Client Object Model and REST API',
#                'num_ratings': u'213'},
#               {'categories': [u'web', u'api'],
#                'course_date': u'Jun 19 2013',
#                'course_length': u'2h 17m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/web-api-design',
#                'course_rating': 5,
#                'course_title': u'Web API Design',
#                'num_ratings': u'1243'},
#               {'categories': [u'web', u'api'],
#                'course_date': u'Jan 27 2015',
#                'course_length': u'1h 43m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/web-audio-api-introduction',
#                'course_rating': 5,
#                'course_title': u'Introduction to the Web Audio API',
#                'num_ratings': u'29'}],
#              u'app': [{'categories': [u'app', u'store'],
#                'course_date': u'Dec 11 2015',
#                'course_length': u'3h 17m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/ios-xamarin-from-start-to-store',
#                'course_rating': 5,
#                'course_title': u'Building Your First Xamarin.iOS App from Start to Store',
#                'num_ratings': u'60'},
#               {'categories': [u'app', u'for', u'store'],
#                'course_date': u'Dec 19 2013',
#                'course_length': u'2h 52m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/deploying-ios-apps',
#                'course_rating': 5,
#                'course_title': u'Deploying iOS Applications for Testing and the App Store',
#                'num_ratings': u'107'},
#               {'categories': [u'asp.net', u'web', u'app', u'angularjs'],
#                'course_date': u'Oct 8 2015',
#                'course_length': u'9h 21m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/aspdotnet-5-ef7-bootstrap-angular-web-app',
#                'course_rating': 5,
#                'course_title': u'Building a Web App with ASP.NET 5, MVC 6, EF7 and AngularJS',
#                'num_ratings': u'1720'},
#               {'categories': [u'app'],
#                'course_date': u'Oct 26 2015',
#                'course_length': u'2h 51m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/build-isomorphic-app-react-flux-webpack-firebase',
#                'course_rating': 5,
#                'course_title': u'Building a Real-time App with React, Flux, Webpack, and Firebase',
#                'num_ratings': u'134'},
#               {'categories': [u'web', u'app', u'on'],
#                'course_date': u'Aug 28 2015',
#                'course_length': u'2h 10m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/reactjs-on-rails-building-full-stack-web-app',
#                'course_rating': 5,
#                'course_title': u'React.js on Rails: Building a Full Stack Web App',
#                'num_ratings': u'84'},
#               {'categories': [u'app'],
#                'course_date': u'Mar 17 2013',
#                'course_length': u'2h 39m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/android-beginner-app-inventor',
#                'course_rating': 5,
#                'course_title': u'Learning to Build Apps with App Inventor',
#                'num_ratings': u'186'},
#               {'categories': [u'app'],
#                'course_date': u'Aug 14 2013',
#                'course_length': u'3h 16m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-mvc4-ios-android-apps-servicestack-xamarin-csharp',
#                'course_rating': 5,
#                'course_title': u'An MVC4, iOS And Android App With ServiceStack, Xamarin and C#',
#                'num_ratings': u'243'},
#               {'categories': [u'app', u'google'],
#                'course_date': u'Jul 27 2014',
#                'course_length': u'3h 8m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/creating-google-glass-app-csharp-xamarin',
#                'course_rating': 5,
#                'course_title': u'Creating a Google Glass App With C# and Xamarin',
#                'num_ratings': u'16'},
#               {'categories': [u'app', u'rails'],
#                'course_date': u'Feb 24 2012',
#                'course_length': u'1h 56m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/play-by-play-aaron-patterson',
#                'course_rating': 5,
#                'course_title': u'Play by Play: Rails App Development with Aaron Patterson',
#                'num_ratings': u'34'},
#               {'categories': [u'app', u'ruby'],
#                'course_date': u'Jan 31 2011',
#                'course_length': u'1h 51m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/play-by-play-john-barnette',
#                'course_rating': 5,
#                'course_title': u'Play by Play: Ruby App Development with John Barnette',
#                'num_ratings': u'14'},
#               {'categories': [u'app', u'ember.js', u'rails'],
#                'course_date': u'Jun 28 2012',
#                'course_length': u'2h 22m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/play-by-play-yehuda-katz',
#                'course_rating': 4,
#                'course_title': u'Play by Play: App Development in Rails and Ember.js with Yehuda Katz',
#                'num_ratings': u'18'},
#               {'categories': [u'app', u'api', u'angular'],
#                'course_date': u'Feb 10 2015',
#                'course_length': u'3h 23m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/two-tier-enterprise-app-api-development-angular-sails',
#                'course_rating': 5,
#                'course_title': u'Two Tier Enterprise App and API Development with Angular &amp; Sails',
#                'num_ratings': u'133'},
#               {'categories': [u'app'],
#                'course_date': u'Nov 18 2013',
#                'course_length': u'3h 20m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/android-dreams-widgets-notifications',
#                'course_rating': 5,
#                'course_title': u'Android Dreams, Widgets and Notifications: Life Outside Your App',
#                'num_ratings': u'43'},
#               {'categories': [u'windows', u'app'],
#                'course_date': u'Jul 15 2014',
#                'course_length': u'3h 42m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/building-your-first-windows-phone-app',
#                'course_rating': 4,
#                'course_title': u'Building Your First Windows Phone App',
#                'num_ratings': u'170'},
#               {'categories': [u'app', u'google'],
#                'course_date': u'Jun 15 2014',
#                'course_length': u'3h 4m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/creating-google-glass-app',
#                'course_rating': 5,
#                'course_title': u'Creating a Google Glass App With the Glass Development Kit',
#                'num_ratings': u'21'},
#               {'categories': [u'app', u'smart'],
#                'course_date': u'Apr 22 2014',
#                'course_length': u'5h 21m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/pebble-smart-watch-app-fundamentals',
#                'course_rating': 4,
#                'course_title': u'Pebble Smart Watch App Fundamentals',
#                'num_ratings': u'15'}],
#              u'application': [{'categories': [u'web',
#                 u'application',
#                 u'realtime'],
#                'course_date': u'Jul 14 2015',
#                'course_length': u'3h 26m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/meteorjs-web-application',
#                'course_rating': 5,
#                'course_title': u'Building a Realtime Web Application with Meteor.js',
#                'num_ratings': u'184'},
#               {'categories': [u'application'],
#                'course_date': u'Jul 7 2015',
#                'course_length': u'2h 23m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/oauth-passport-securing-application',
#                'course_rating': 5,
#                'course_title': u'Securing Your Application with OAuth and Passport',
#                'num_ratings': u'83'},
#               {'categories': [u'application'],
#                'course_date': u'May 13 2015',
#                'course_length': u'3h 53m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/swift-ios-application-real-world',
#                'course_rating': 4,
#                'course_title': u'Building a Real World iOS Application with Swift',
#                'num_ratings': u'156'},
#               {'categories': [u'on', u'application', u'java', u'server'],
#                'course_date': u'May 6 2015',
#                'course_length': u'2h 54m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/java-ee-websphere-application-server-getting-started',
#                'course_rating': 5,
#                'course_title': u'Getting Started With Java EE on WebSphere\xae Application Server',
#                'num_ratings': u'98'},
#               {'categories': [u'application'],
#                'course_date': u'Apr 30 2015',
#                'course_length': u'3h 51m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/excel-application-development-vba',
#                'course_rating': 4,
#                'course_title': u'Excel Application Development with VBA',
#                'num_ratings': u'57'},
#               {'categories': [u'application'],
#                'course_date': u'Aug 28 2013',
#                'course_length': u'4h 35m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/application-instrumentation-log4net',
#                'course_rating': 5,
#                'course_title': u'Application Instrumentation using log4net',
#                'num_ratings': u'256'},
#               {'categories': [u'application'],
#                'course_date': u'Jan 26 2015',
#                'course_length': u'4h 24m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/application-instrumentation-using-performance-counters',
#                'course_rating': 5,
#                'course_title': u'Application Instrumentation Using Performance Counters',
#                'num_ratings': u'33'},
#               {'categories': [u'application'],
#                'course_date': u'May 28 2012',
#                'course_length': u'3h 45m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/async-parallel-app-design',
#                'course_rating': 5,
#                'course_title': u'Async and Parallel Programming: Application Design',
#                'num_ratings': u'601'},
#               {'categories': [u'application'],
#                'course_date': u'Feb 15 2012',
#                'course_length': u'2h 48m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/brownfield',
#                'course_rating': 5,
#                'course_title': u'Brownfield Application Development',
#                'num_ratings': u'122'},
#               {'categories': [u'asp.net', u'framework', u'application'],
#                'course_date': u'Mar 12 2014',
#                'course_length': u'3h 25m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/build-application-framework-aspdotnet-mvc-5',
#                'course_rating': 5,
#                'course_title': u'Build Your Own Application Framework with ASP.NET MVC 5',
#                'num_ratings': u'884'},
#               {'categories': [u'application'],
#                'course_date': u'Apr 30 2013',
#                'course_length': u'2h 41m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-real-kinect-application',
#                'course_rating': 5,
#                'course_title': u'Building a Real Application With Kinect',
#                'num_ratings': u'87'},
#               {'categories': [u'windows', u'application'],
#                'course_date': u'Sep 24 2013',
#                'course_length': u'3h 25m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-real-world-windows8-application-mvvm',
#                'course_rating': 5,
#                'course_title': u'Building A Real-World Windows 8 Application Architecture Using MVVM',
#                'num_ratings': u'139'},
#               {'categories': [u'application'],
#                'course_date': u'Apr 26 2012',
#                'course_length': u'1h 10m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/caching-block',
#                'course_rating': 5,
#                'course_title': u'Enterprise Library Caching Application Block',
#                'num_ratings': u'63'},
#               {'categories': [u'application'],
#                'course_date': u'Mar 15 2012',
#                'course_length': u'1h 2m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/data-access-block',
#                'course_rating': 4,
#                'course_title': u'Enterprise Library Data Access Application Block',
#                'num_ratings': u'98'},
#               {'categories': [u'application'],
#                'course_date': u'Apr 16 2012',
#                'course_length': u'1h 17m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/exception-handling',
#                'course_rating': 5,
#                'course_title': u'Enterprise Library Exception Handling Application Block',
#                'num_ratings': u'137'},
#               {'categories': [u'framework', u'cross', u'c++', u'application'],
#                'course_date': u'May 29 2014',
#                'course_length': u'4h 19m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/introduction-qt-cplusplus-framework',
#                'course_rating': 5,
#                'course_title': u'Introduction to Qt: A C++ Cross Platform Application Framework',
#                'num_ratings': u'212'},
#               {'categories': [u'application'],
#                'course_date': u'Apr 19 2012',
#                'course_length': u'1h 30m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/logging-block',
#                'course_rating': 4,
#                'course_title': u'Enterprise Library Logging Application Block',
#                'num_ratings': u'153'},
#               {'categories': [u'application'],
#                'course_date': u'Jul 10 2014',
#                'course_length': u'2h 30m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/node-application-patterns',
#                'course_rating': 5,
#                'course_title': u'Node Application Patterns',
#                'num_ratings': u'314'},
#               {'categories': [u'asp.net', u'web', u'for', u'application'],
#                'course_date': u'Apr 29 2013',
#                'course_length': u'8h 6m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/owasp-top10-aspdotnet-application-security-risks',
#                'course_rating': 5,
#                'course_title': u'OWASP Top 10 Web Application Security Risks for ASP.NET',
#                'num_ratings': u'904'},
#               {'categories': [u'application', u'angularjs'],
#                'course_date': u'Dec 12 2013',
#                'course_length': u'2h 14m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/play-by-play-wahlin-allen',
#                'course_rating': 5,
#                'course_title': u'Play by Play: AngularJS Application Design with Scott Allen and Dan Wahlin',
#                'num_ratings': u'521'},
#               {'categories': [u'application'],
#                'course_date': u'Dec 18 2013',
#                'course_length': u'2h 23m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/play-by-play-wildermuth',
#                'course_rating': 5,
#                'course_title': u'Play by Play: Application Development with Shawn Wildermuth',
#                'num_ratings': u'263'},
#               {'categories': [u'application', u'backbone.js'],
#                'course_date': u'Feb 8 2013',
#                'course_length': u'4h 26m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/playing-with-backbonejs',
#                'course_rating': 5,
#                'course_title': u'Application Building Patterns with Backbone.js',
#                'num_ratings': u'160'},
#               {'categories': [u'python', u'application'],
#                'course_date': u'Sep 3 2014',
#                'course_length': u'1h 42m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/python-desktop-application-development',
#                'course_rating': 5,
#                'course_title': u'Python Desktop Application Development',
#                'num_ratings': u'366'},
#               {'categories': [u'rapid', u'sharepoint', u'application'],
#                'course_date': u'Oct 10 2013',
#                'course_length': u'1h 43m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/rapid-application-prototyping-sharepoint-lightswitch',
#                'course_rating': 4,
#                'course_title': u'Rapid Application Prototyping with SharePoint and LightSwitch',
#                'num_ratings': u'94'},
#               {'categories': [u'application'],
#                'course_date': u'May 16 2012',
#                'course_length': u'1h 8m',
# ...
#                'course_title': u'Windows Azure Service Bus',
#                'num_ratings': u'200'},
#               {'categories': [u'windows'],
#                'course_date': u'Jan 23 2011',
#                'course_length': u'2h 25m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/beginner-azure',
#                'course_rating': 4,
#                'course_title': u'Introduction to Windows Azure',
#                'num_ratings': u'573'},
#               {'categories': [u'windows', u'server'],
#                'course_date': u'Mar 6 2011',
#                'course_length': u'1h 45m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/biztalk-azure-appfabric',
#                'course_rating': 5,
#                'course_title': u'Integrating BizTalk Server with Windows Azure AppFabric',
#                'num_ratings': u'14'},
#               {'categories': [u'windows'],
#                'course_date': u'Oct 22 2013',
#                'course_length': u'3h 5m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-windows-phone-apps-stand-out',
#                'course_rating': 4,
#                'course_title': u'Building Windows Phone Apps that Stand Out',
#                'num_ratings': u'40'},
#               {'categories': [u'windows', u'app'],
#                'course_date': u'Jul 15 2014',
#                'course_length': u'3h 42m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/building-your-first-windows-phone-app',
#                'course_rating': 4,
#                'course_title': u'Building Your First Windows Phone App',
#                'num_ratings': u'170'},
#               {'categories': [u'windows', u'for'],
#                'course_date': u'Jul 14 2014',
#                'course_length': u'3h 16m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/github-windows-developers',
#                'course_rating': 5,
#                'course_title': u'GitHub for Windows Developers',
#                'num_ratings': u'343'},
#               {'categories': [u'windows'],
#                'course_date': u'Jan 14 2015',
#                'course_length': u'2h 23m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/optical-character-recognition-windows-runtime',
#                'course_rating': 5,
#                'course_title': u'Optical Character Recognition with Windows Runtime',
#                'num_ratings': u'24'},
#               {'categories': [u'windows', u'server'],
#                'course_date': u'Oct 14 2012',
#                'course_length': u'2h 18m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/powershell-top-10',
#                'course_rating': 4,
#                'course_title': u'Top 10 Cool PowerShell v3 Features with Windows Server 2012',
#                'num_ratings': u'27'},
#               {'categories': [u'windows'],
#                'course_date': u'Jun 20 2013',
#                'course_length': u'1h 35m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/programming-telerik-windows8-xaml-controls',
#                'course_rating': 5,
#                'course_title': u'Telerik XAML Windows 8 Controls',
#                'num_ratings': u'18'},
#               {'categories': [u'windows'],
#                'course_date': u'Jan 20 2014',
#                'course_length': u'2h 45m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/telerik-windows-phone8-controls-core',
#                'course_rating': 5,
#                'course_title': u'Core Telerik Windows Phone 8 Controls',
#                'num_ratings': u'13'},
#               {'categories': [u'windows', u'sharepoint'],
#                'course_date': u'Jul 11 2013',
#                'course_length': u'4h 47m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/using-windows-powershell-sharepoint-2010-2013',
#                'course_rating': 5,
#                'course_title': u'Using Windows PowerShell with SharePoint 2010 and SharePoint 2013',
#                'num_ratings': u'86'},
#               {'categories': [u'windows', u'new'],
#                'course_date': u'Oct 31 2013',
#                'course_length': u'2h 36m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/whats-new-windows-embedded8-standard',
#                'course_rating': 4,
#                'course_title': u"What's new in Windows Embedded 8 Standard",
#                'num_ratings': u'14'},
#               {'categories': [u'windows', u'management'],
#                'course_date': u'Dec 17 2012',
#                'course_length': u'3h 25m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/win8-bgproc',
#                'course_rating': 5,
#                'course_title': u'Windows 8 Background Processing and Lifecycle Management',
#                'num_ratings': u'32'},
#               {'categories': [u'windows', u'application'],
#                'course_date': u'Apr 22 2012',
#                'course_length': u'3h 46m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/win8appdata',
#                'course_rating': 4,
#                'course_title': u'Windows 8 Metro Application Data',
#                'num_ratings': u'17'},
#               {'categories': [u'windows'],
#                'course_date': u'Nov 19 2012',
#                'course_length': u'5h 16m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/win8mvvm',
#                'course_rating': 5,
#                'course_title': u'Building Windows 8 MVVM XAML Apps',
#                'num_ratings': u'318'},
#               {'categories': [u'windows'],
#                'course_date': u'Oct 23 2012',
#                'course_length': u'3h 22m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/win8sellingapps',
#                'course_rating': 4,
#                'course_title': u'Selling Windows 8 Apps',
#                'num_ratings': u'25'},
#               {'categories': [u'windows', u'service'],
#                'course_date': u'Apr 24 2013',
#                'course_length': u'2h 46m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/windows-azure-infrastructure-service-introduction',
#                'course_rating': 4,
#                'course_title': u'Introduction to Windows Azure Infrastructure as a Service',
#                'num_ratings': u'277'},
#               {'categories': [u'windows', u'storage'],
#                'course_date': u'Mar 5 2014',
#                'course_length': u'6h 51m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/windows-azure-storage-in-depth',
#                'course_rating': 5,
#                'course_title': u'Windows Azure Storage In-Depth',
#                'num_ratings': u'174'},
#               {'categories': [u'windows'],
#                'course_date': u'Oct 9 2013',
#                'course_length': u'4h 34m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/windows-embedded81-industry-jumpstart',
#                'course_rating': 5,
#                'course_title': u'Windows Embedded 8.1 Industry Jumpstart',
#                'num_ratings': u'13'},
#               {'categories': [u'windows', u'management'],
#                'course_date': u'Dec 11 2013',
#                'course_length': u'3h 26m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/windows-phone-testing-error-management',
#                'course_rating': 5,
#                'course_title': u'Windows Phone Testing and Error Management',
#                'num_ratings': u'22'},
#               {'categories': [u'windows'],
#                'course_date': u'May 4 2010',
#                'course_length': u'4h 21m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/windows7-developer-tutorial',
#                'course_rating': 5,
#                'course_title': u'Introduction to Windows 7 Development',
#                'num_ratings': u'39'},
#               {'categories': [u'windows'],
#                'course_date': u'Apr 19 2013',
#                'course_length': u'3h 31m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/windows8-contracts',
#                'course_rating': 5,
#                'course_title': u'Contracts and Extensions in Windows 8',
#                'num_ratings': u'23'},
#               {'categories': [u'windows', u'store'],
#                'course_date': u'Jan 27 2013',
#                'course_length': u'5h 48m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/windows8-hands-on',
#                'course_rating': 5,
#                'course_title': u'Windows 8 Store Apps Hands-on in 20 Lessons',
#                'num_ratings': u'141'},
#               {'categories': [u'windows'],
#                'course_date': u'Oct 31 2009',
#                'course_length': u'4h 41m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/workflow-by-example',
#                'course_rating': 4,
#                'course_title': u'Windows Workflow 3.5 by Example',
#                'num_ratings': u'29'},
#               {'categories': [u'windows'],
#                'course_date': u'Feb 6 2011',
#                'course_length': u'1h 36m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/wp7-databinding',
#                'course_rating': 4,
#                'course_title': u'Windows Phone 7 Data Binding',
#                'num_ratings': u'16'},
#               {'categories': [u'windows'],
#                'course_date': u'Apr 17 2011',
#                'course_length': u'3h 5m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/wp7-handson',
#                'course_rating': 5,
#                'course_title': u'Hands-on Windows Phone 7 Development',
#                'num_ratings': u'15'},
#               {'categories': [u'windows'],
#                'course_date': u'Dec 10 2010',
#                'course_length': u'2h 53m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/wp7-intro',
#                'course_rating': 4,
#                'course_title': u'Windows Phone 7 Basics',
#                'num_ratings': u'72'},
#               {'categories': [u'windows'],
#                'course_date': u'Sep 5 2011',
#                'course_length': u'2h 51m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/wp75-data',
#                'course_rating': 5,
#                'course_title': u'Windows Phone 7.5 Data',
#                'num_ratings': u'18'}],
#              u'wix': [{'categories': [u'wix'],
#                'course_date': u'Mar 9 2015',
#                'course_length': u'3h 31m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/wix-introduction',
#                'course_rating': 5,
#                'course_title': u'Introduction to the WiX Toolset',
#                'num_ratings': u'174'}],
#              u'wonderful': [{'categories': [u'wonderful'],
#                'course_date': u'Dec 16 2015',
#                'course_length': u'2h 20m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/alan-turing-wonderful-machine',
#                'course_rating': 5,
#                'course_title': u"Alan Turing's Wonderful Machine",
#                'num_ratings': u'28'}],
#              u'wordpress': [{'categories': [u'wordpress'],
#                'course_date': u'May 14 2015',
#                'course_length': u'1h 45m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/wordpress-fundamentals-wp-query-loop',
#                'course_rating': 5,
#                'course_title': u'WordPress Fundamentals: WP_Query and the Loop',
#                'num_ratings': u'34'},
#               {'categories': [u'framework', u'bootstrap', u'wordpress'],
#                'course_date': u'Apr 16 2014',
#                'course_length': u'5h 10m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-wordpress-theme-framework-bootstrap3',
#                'course_rating': 5,
#                'course_title': u'Building a WordPress Theme Framework with Bootstrap 3',
#                'num_ratings': u'113'},
#               {'categories': [u'wordpress'],
#                'course_date': u'Nov 10 2013',
#                'course_length': u'59m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/user-roles-capabilities-wordpress',
#                'course_rating': 5,
#                'course_title': u'Master Your Domain: User Roles &amp; Capabilities in WordPress',
#                'num_ratings': u'27'},
#               {'categories': [u'code', u'wordpress'],
#                'course_date': u'Oct 11 2013',
#                'course_length': u'55m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/custom-content-types-code-like-wordpress-ninja',
#                'course_rating': 4,
#                'course_title': u'Custom Content Types and You: How to Code like A WordPress Ninja',
#                'num_ratings': u'73'},
#               {'categories': [u'wordpress'],
#                'course_date': u'Jun 25 2014',
#                'course_length': u'2h 41m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/getting-first-wordpress-website-up',
#                'course_rating': 5,
#                'course_title': u'Getting Your First WordPress Website Up in Under 24 Hours',
#                'num_ratings': u'276'},
#               {'categories': [u'wordpress'],
#                'course_date': u'Dec 30 2013',
#                'course_length': u'1h 50m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/mastering-wordpress-multisite',
#                'course_rating': 5,
#                'course_title': u'WordPress as a Network: Mastering WordPress Multisite',
#                'num_ratings': u'37'},
#               {'categories': [u'wordpress'],
#                'course_date': u'Jul 26 2013',
#                'course_length': u'43m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/wordpress-internationalization',
#                'course_rating': 4,
#                'course_title': u'Internationalization in WordPress',
#                'num_ratings': u'23'},
#               {'categories': [u'wordpress'],
#                'course_date': u'May 8 2013',
#                'course_length': u'1h 22m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/wordpress-introduction',
#                'course_rating': 4,
#                'course_title': u'Introduction to WordPress',
#                'num_ratings': u'610'},
#               {'categories': [u'wordpress'],
#                'course_date': u'Jun 28 2013',
#                'course_length': u'1h 23m',
#                'course_level': u'Beginner',
#                'course_link': u'/courses/wordpress-plugin-development-introduction',
#                'course_rating': 4,
#                'course_title': u'Introduction to WordPress Plugin Development',
#                'num_ratings': u'141'}],
#              u'zend': [{'categories': [u'framework', u'php', u'zend'],
#                'course_date': u'Feb 25 2014',
#                'course_length': u'3h 10m',
#                'course_level': u'Intermediate',
#                'course_link': u'/courses/building-php-applications-zend-framework',
#                'course_rating': 4,
#                'course_title': u'Building PHP Applications with Zend Framework 2',
#                'num_ratings': u'88'}]})
